# %% [markdown]
# <a href="https://colab.research.google.com/github/filipecarbonera/formacao_python/blob/main/rascunhos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from pandas.core.frame import DataFrame
cht = pd.read_csv('/content/sample_data/california_housing_test.csv')
df = cht
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
cht.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
cht['longitude']
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64

# %%
type(cht['longitude'])
# Out:
# pandas.core.series.Series

# %%
cht[['longitude']]
# Out:
#       longitude
# 0       -122.05
# 1       -118.30
# 2       -117.81
# 3       -118.36
# 4       -119.67
# ...         ...
# 2995    -119.86
# 2996    -118.14
# 2997    -119.70
# 2998    -117.12
# 2999    -119.63
#
# [3000 rows x 1 columns]

# %%
type(cht[['longitude']])
# Out:
# pandas.core.frame.DataFrame

# %%
cht[['longitude', 'latitude']]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df[2:9]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
#
#    population  households  median_income  median_house_value
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0
# 5       663.0       204.0         1.6635             67000.0
# 6       604.0       218.0         1.6641             67000.0
# ...

# %%
df[50:]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 50      -120.99     37.70                14.0       9849.0          1887.0
# 51      -119.42     35.97                21.0        554.0           121.0
# 52      -122.21     37.80                39.0       2003.0           500.0
# 53      -118.17     33.80                26.0       1589.0           380.0
# 54      -117.90     34.09                39.0       1726.0           333.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df[6::30]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6       -121.43     38.63                43.0       1009.0           225.0
# 36      -122.53     37.97                52.0       1560.0           451.0
# 66      -121.08     37.69                19.0       6473.0          1212.0
# 96      -120.21     36.77                20.0       1745.0           348.0
# 126     -120.93     37.73                14.0       2799.0           618.0
# ...         ...       ...                 ...          ...             ...
# 2856    -118.15     33.95                31.0       1053.0           230.0
# 2886    -118.45     34.18                34.0       1843.0           442.0
# 2916    -121.92     36.95                29.0       3457.0           699.0
# 2946    -118.31     34.09                36.0       2517.0           842.0
# 2976    -118.31     34.05                35.0       1692.0           423.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df.loc[[2]]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2    -117.81     33.78                27.0       3589.0           507.0
#
#    population  households  median_income  median_house_value
# 2      1484.0       495.0         5.7934            270500.0

# %%
df.loc[[2],['total_rooms','median_income']]
# Out:
#    total_rooms  median_income
# 2       3589.0         5.7934

# %%
df.loc[:,['longitude','latitude']]
# Out:
#       longitude  latitude
# 0       -122.05     37.37
# 1       -118.30     34.26
# 2       -117.81     33.78
# 3       -118.36     33.82
# 4       -119.67     36.33
# ...         ...       ...
# 2995    -119.86     34.42
# 2996    -118.14     34.06
# 2997    -119.70     36.30
# 2998    -117.12     34.10
# 2999    -119.63     34.42
#
# [3000 rows x 2 columns]

# %%
df.iloc[[2]]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2    -117.81     33.78                27.0       3589.0           507.0
#
#    population  households  median_income  median_house_value
# 2      1484.0       495.0         5.7934            270500.0

# %%
def escolhe_colunas(df, coluna_inicio, coluna_fim):
  dft = df.T.iloc[coluna_inicio:coluna_fim].T
  return(dft)

# %%
escolhe_colunas(df,3,7)
# Out:
#       total_rooms  total_bedrooms  population  households
# 0          3885.0           661.0      1537.0       606.0
# 1          1510.0           310.0       809.0       277.0
# 2          3589.0           507.0      1484.0       495.0
# 3            67.0            15.0        49.0        11.0
# 4          1241.0           244.0       850.0       237.0
# ...           ...             ...         ...         ...
# 2995       1450.0           642.0      1258.0       607.0
# 2996       5257.0          1082.0      3496.0      1036.0
# 2997        956.0           201.0       693.0       220.0
# 2998         96.0            14.0        46.0        14.0
# 2999       1765.0           263.0       753.0       260.0
#
# [3000 rows x 4 columns]

# %%
df = pd.read_csv('https://raw.githubusercontent.com/filipecarbonera/formacao_python/main/dados/db.csv', sep = ';')
df.head()
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
string = str(df[['Acessórios']].T[4])
string
# Out:
# "Acessórios    ['Rodas de liga', '4 X 4', 'Central multimídia...\nName: 4, dtype: object"

# %%
df[['Acessórios']]
# Out:
#                                             Acessórios
# 0    ['Rodas de liga', 'Travas elétricas', 'Piloto ...
# 1    ['Central multimídia', 'Teto panorâmico', 'Fre...
# 2    ['Piloto automático', 'Controle de estabilidad...
# 3    ['Travas elétricas', '4 X 4', 'Vidros elétrico...
# 4    ['Rodas de liga', '4 X 4', 'Central multimídia...
# ..                                                 ...
# 253  ['Controle de estabilidade', 'Piloto automátic...
# 254  ['Bancos de couro', 'Painel digital', 'Sensor ...
# 255  ['Rodas de liga', 'Controle de tração', 'Câmbi...
# 256  ['Ar condicionado', '4 X 4', 'Câmbio automátic...
# 257  ['Central multimídia', 'Teto panorâmico', 'Vid...
#
# [258 rows x 1 columns]
